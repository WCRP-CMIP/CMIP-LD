# %%
from pprint import pprint
import cmipld

# %%
# ctx = cmipld.generate_context()

# %%
from ptqdm import imap
from pyld import jsonld

def fetch(url):
    return jsonld.expand(url)

imap(fetch, cmipld.mapping.values())
# Out:
#   Cell In[13], line 4
#
#     ^
# SyntaxError: incomplete input
