# %%
import cmipld

# %%
cmipld.processor.get('https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/atmos.json')
# Out:
# {}
# [{'@context': {'@context': {'@base': 'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/',
#     '@vocab': 'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/',
#     'id': '@id',
#     'type': '@type'},
#    '@embed': '@always'},
#   'id': 'atmos',
#   'type': 'realm',
#   'description': 'Atmosphere',
#   'name': 'atmos'}]

# %%
links = cmipld.processor.depends('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld') 
# linktest/test2
links
# Out:
# {}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 links = cmipld.processor.get('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld')
#       2 # linktest/test2
#       3 links
#
# File ~/WIPwork/CMIP-LD/cmipld/browse/read.py:131, in JsonLdProcessor.get(self, uid, **kwargs)
#     128 print(kwargs)
#     129 # if arg in locations, then use that and give that level.
# --> 131 return self.expand_document(uid,**kwargs)
#
# File ~/WIPwork/CMIP-LD/cmipld/browse/read.py:167, in JsonLdProcessor.expand_document(self, jsonld_doc, compact, expand_ctx, expand_links, is_nested)
#     163 if compact and not is_nested:
#     164     base_url = self._extract_base_url(jsonld_doc) if isinstance(jsonld_doc, str) else None
#     165     processed_item = jsonld.compact(
#     166         processed_item,
# --> 167         doc['@context'],
#     168         options={'base': base_url} if base_url else {}
#     169     )
#     171 if isinstance(processed_item, dict):
#     172     processed_item = json.loads(
#     173         re.sub(r'"context"', '"@context"', json.dumps(processed_item))
#     174     )
#
# TypeError: list indices must be integers or slices, not str

# %%
import requests

def url_exists(url):
    try:
        response = requests.head(url, allow_redirects=True, timeout=5)
        return response.status_code == 200
    except requests.ConnectionError:
        return None
    except requests.Timeout:
        return None
    except requests.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
from tqdm import tqdm

missing = [link for link in tqdm(links) if not url_exists(link)]

missing
# Out:
# 0it [00:00, ?it/s]
# []
