# %%
import cmipld

# %%
cmipld.processor.get('https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/atmos.json')
# Out:
# {}
# [{'@context': {'@context': {'@base': 'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/',
#     '@vocab': 'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/',
#     'id': '@id',
#     'type': '@type'},
#    '@embed': '@always'},
#   'id': 'atmos',
#   'type': 'realm',
#   'description': 'Atmosphere',
#   'name': 'atmos'}]

# %%
links = cmipld.processor.depends('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld') 
# linktest/test2

# rm self option to get all

links
# Out:
# {}
# {'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/1hr',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/1hrcm',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/1hrpt',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/3hr',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/3hrpt',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/6hr',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/6hrpt',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/day',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/dec',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/fx',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/mon',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/monc',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/monpt',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/subhrpt',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/yr',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/frequency/yrpt',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/linktest/test1',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/linktest/test2',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/mip_era/cmip5',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/mip_era/cmip6',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/mip_era/cmip6plus',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/mip_era/cmip7',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/product/derived',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/product/forcing_dataset',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/product/model_output',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/product/observations',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/aerosol',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/atmos',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/atmoschem',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/land',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/landice',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/ocean',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/ocnbgchem',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/rivers',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/seaice',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/0.5km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/10000km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/1000km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/100km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/10km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/1km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/1x1degree',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/2.5km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/2500km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/250km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/25km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/5000km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/500km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/50km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/resolution/5km',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/aer',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/agcm',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/aogcm',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/bgc',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/chem',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/ism',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/land',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/ogcm',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/rad',
#  'https://wcrp-cmip.github.io/WCRP-UNIVERSE/source_type/slab'}

# %%
cmipld.processor.find_missing('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld')
# Out:
# {}
# 100%|██████████| 60/60 [00:18<00:00,  3.28it/s]
# ['https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/rivers']

# %%
import cmipld
cmipld.processor.get('wcrp-universe')
# Out:
# {}
# ---------------------------------------------------------------------------
# JsonLdError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import cmipld
# ----> 2 cmipld.processor.get('wcrp-universe')
#
# File ~/WIPwork/CMIP-LD/cmipld/browse/read.py:145, in JsonLdProcessor.get(self, query, **kwargs)
#     141     print('Substituting prefix:')
#     142     print(match,query)
# --> 145 return self.expand_document(query,**kwargs)
#
# File ~/WIPwork/CMIP-LD/cmipld/browse/read.py:166, in JsonLdProcessor.expand_document(self, jsonld_doc, compact, expand_ctx, expand_links, is_nested)
#     147 def expand_document(self,
#     148                    jsonld_doc: Union[str, Dict],
#     149                    compact: bool = True,
#     150                    expand_ctx: bool = True,
#     151                    expand_links: bool = True,
#     152                    is_nested: bool = False) -> List[Dict]:
#     153     """
#     154     Expand a JSON-LD document and resolve all referenced URLs.
#     155
#    (...)
#     164         List of processed documents
#     165     """
# --> 166     doc = self._load_document(jsonld_doc) if isinstance(jsonld_doc, str) else jsonld_doc
#     168     expanded = jsonld.expand(jsonld_doc, options={'defaultLoader': self.loader})
#     170     processed = []
#
# File ~/WIPwork/CMIP-LD/cmipld/browse/read.py:55, in JsonLdProcessor._load_document(self, url)
#      44 @lru_cache(maxsize=100)
#      45 def _load_document(self, url: str) -> Dict:
#      46     """
#      47     Load and cache a JSON-LD document from a URL.
#      48
#    (...)
#      53         The loaded document
#      54     """
# ---> 55     return self.loader(url)['document']
#
# File ~/customlib/homebrew/Caskroom/mambaforge/base/lib/python3.10/site-packages/pyld/documentloader/requests.py:98, in requests_document_loader.<locals>.loader(url, options)
#      96     return doc
#      97 except JsonLdError as e:
# ---> 98     raise e
#      99 except Exception as cause:
#     100     raise JsonLdError(
#     101         'Could not retrieve a JSON-LD document from the URL.',
#     102         'jsonld.LoadDocumentError', code='loading document failed',
#     103         cause=cause)
#
# File ~/customlib/homebrew/Caskroom/mambaforge/base/lib/python3.10/site-packages/pyld/documentloader/requests.py:47, in requests_document_loader.<locals>.loader(url, options)
#      42 pieces = urllib_parse.urlparse(url)
#      43 if (not all([pieces.scheme, pieces.netloc]) or
#      44     pieces.scheme not in ['http', 'https'] or
#      45     set(pieces.netloc) > set(
#      46         string.ascii_letters + string.digits + '-.:')):
# ---> 47     raise JsonLdError(
#      48         'URL could not be dereferenced; only "http" and "https" '
#      49         'URLs are supported.',
#      50         'jsonld.InvalidUrl', {'url': url},
#      51         code='loading document failed')
#      52 if secure and pieces.scheme != 'https':
#      53     raise JsonLdError(
#      54         'URL could not be dereferenced; secure mode enabled and '
#      55         'the URL\'s scheme is not "https".',
#      56         'jsonld.InvalidUrl', {'url': url},
#      57         code='loading document failed')
#
# JsonLdError: ('URL could not be dereferenced; only "http" and "https" URLs are supported.',)
# Type: jsonld.InvalidUrl
# Code: loading document failed
# Details: {'url': 'wcrp-universe'}

# %%
# jsonld.expand('https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/graph.jsonld')

# %%
jsonld.frame('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld', {"@id": "https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/atmos"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 jsonld.frame('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld', {"@id": "https://wcrp-cmip.github.io/WCRP-UNIVERSE/realm/atmos"})
#
# NameError: name 'jsonld' is not defined

# %%
jsonld.frame('https://wcrp-cmip.github.io/WCRP-UNIVERSE/graph.jsonld', {"@id": "https://wcrp-cmip.github.io/WCRP-UNIVERSE/linktest/test2","@embed":"@always"})
